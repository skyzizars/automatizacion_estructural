# %% [markdown]
# # Análisis Sísmico

# %%
#Importar las librerías necesarias
# %load_ext autoreload
# %autoreload 2
import os
import sys
sys.path.append(os.getcwd()+'\\..')
from lib import etabs_utils as etb
from lib import sismo_utils as sis
#from mem import sismo_mem as smem
from ipywidgets import widgets
from IPython.display import display

# %%
import comtypes
EtabsObject=comtypes.client.GetActiveObject("CSI.ETABS.API.ETABSObject")
SapModel=EtabsObject.SapModel

# %%
etb.get_table(SapModel,"Story Forces")
# Out:
# (('Story',
#   'OutputCase',
#   'CaseType',
#   'StepType',
#   'StepNumber',
#   'StepLabel',
#   'Location',
#   'P',
#   'VX',
#   'VY',
#   'T',
#   'MX',
#   'MY'),
#       Story OutputCase     CaseType StepType StepNumber StepLabel Location  P  \
#  0   Story4         Sx    LinStatic      Max       None      None      Top  0
#  1   Story4         Sx    LinStatic      Max       None      None   Bottom  0
#  2   Story4         Sx    LinStatic      Min       None      None      Top  0
#  3   Story4         Sx    LinStatic      Min       None      None   Bottom  0
#  4   Story4         Sy    LinStatic      Max       None      None      Top  0
#  5   Story4         Sy    LinStatic      Max       None      None   Bottom  0
#  6   Story4         Sy    LinStatic      Min       None      None      Top  0
#  7   Story4         Sy    LinStatic      Min       None      None   Bottom  0
#  8   Story4        SDx  LinRespSpec      Max       None      None      Top  0
#  9   Story4        SDx  LinRespSpec      Max       None      None   Bottom  0
#  10  Story4        SDy  LinRespSpec      Max       None      None      Top  0
#  11  Story4        SDy  LinRespSpec      Max       None      None   Bottom  0
#  12  Story3         Sx    LinStatic      Max       None      None      Top  0
#  13  Story3         Sx    LinStatic      Max       None      None   Bottom  0
#  14  Story3         Sx    LinStatic      Min       None      None      Top  0
#  15  Story3         Sx    LinStatic      Min       None      None   Bottom  0
#  16  Story3         Sy    LinStatic      Max       None      None      Top  0
#  17  Story3         Sy    LinStatic      Max       None      None   Bottom  0
#  18  Story3         Sy    LinStatic      Min       None      None      Top  0
#  19  Story3         Sy    LinStatic      Min       None      None   Bottom  0
#  20  Story3        SDx  LinRespSpec      Max       None      None      Top  0
#  21  Story3        SDx  LinRespSpec      Max       None      None   Bottom  0
#  22  Story3        SDy  LinRespSpec      Max       None      None      Top  0
#  23  Story3        SDy  LinRespSpec      Max       None      None   Bottom  0
#  24  Story2         Sx    LinStatic      Max       None      None      Top  0
#  25  Story2         Sx    LinStatic      Max       None      None   Bottom  0
#  26  Story2         Sx    LinStatic      Min       None      None      Top  0
#  27  Story2         Sx    LinStatic      Min       None      None   Bottom  0
#  28  Story2         Sy    LinStatic      Max       None      None      Top  0
#  29  Story2         Sy    LinStatic      Max       None      None   Bottom  0
#  30  Story2         Sy    LinStatic      Min       None      None      Top  0
#  31  Story2         Sy    LinStatic      Min       None      None   Bottom  0
#  32  Story2        SDx  LinRespSpec      Max       None      None      Top  0
#  33  Story2        SDx  LinRespSpec      Max       None      None   Bottom  0
#  34  Story2        SDy  LinRespSpec      Max       None      None      Top  0
#  35  Story2        SDy  LinRespSpec      Max       None      None   Bottom  0
#  38  -31064688.75             0   363800000000          0.01  -185000000000
#  39  -31064688.75             0   363800000000          0.02  -278200000000
#  40             0  -31064688.75  -363800000000  185000000000          -0.01
#  41             0  -31064688.75  -363800000000  278200000000          -0.02
#  42             0  -31064688.75  -381800000000  185000000000          -0.02
#  43             0  -31064688.75  -381800000000  278200000000          -0.03
#  44     2643507.8      0.003916    32488622174          0.31    15674901743
#  45     2643507.8      0.003916    32488622174            32    23463276289
#  46     0.0003142    2643507.74    32488621513   15674901424      0.0001726
#  47     0.0003142    2643507.74    32488621513   23463275811             64  )

# %%
SapModel.Analyze.RunAnalysis();
sismo = sis.sismo_e30()

# %% [markdown]
# # Parámetros de Sitio
#
# ## Zonificación
# ![Factor de Zonifiación](./factor_zona.png)

# %% [markdown]
# ## Factor de Suelo
# ![Factor de Suelo](./factor_suelo.png)

# %% [markdown]
# ## Periodos del suelo
# ![Periodos del Suelo](./periodos_suelo.png)

# %% [markdown]
# ## Sistema Estructural
# ![Sistema Estructural](./sistemas_estructurales.png)

# %% [markdown]
# ## Factor de Amplificación sísmica
# ![Factor de Amplificacion Sísmica](./amplificacion_sismica.png)

# %% [markdown]
# ## Factor de Importancia
# ![Factor de Importancia](./factor_importancia.png)

# %%
sismo.parametros_e30()
# Out:
# VBox(children=(Dropdown(description='Factor Zona', index=3, options=('1', '2', '3', '4'), style=DescriptionSty…

# %% [markdown]
# # Irregularidades

# %%
sismo.irregularidades_e30()
# Out:
# HBox(children=(VBox(children=(HTML(value='<b>Irregularidad en Altura</b>'), Checkbox(value=False, description=…

# %% [markdown]
# # Parámetros Sísmicos

# %%
sismo.show_params()
# Out:
# Parámetros de sitio:
# Factor de zona:
#     Z=0.45
# Factor de Importancia:
#     U=1.00
# Factor de Suelo:
#     S=1.05
# Periodos del Suelo:
#     Tp=0.60
#     Tl=2.00
# Factor Básico de Reducción:
#     Rox=8.00
#     Roy=8.00
# Irregularidad en planta:
#     Ipx=1.00
#     Ipy=1.00
# Irregularidad en altura:
#     Iax=1.00
#     Iay=1.00
# Factor de Reducción:
#     Rx=8.00
#     Ry=8.00

# %%
sismo.analisis_sismo(SapModel)
# Out:
# Análisis Modal:
# Masa Participativa X: 1.00
# Masa Participativa Y: 1.00
# Periodo y deformaxión X: Tx=0.560, Ux=0.816
# Periodo y deformaxión Y: Ty=0.560, Uy=0.009
# Factor de Reduccion con Irregularidades: R=8.0
# C en X: 2.50
# C en Y: 2.50
#
# Coeficiente de sismo estático X: 0.148
# Coeficiente de sismo estático Y: 0.148
# Exponente de altura X: 1.03
# Exponente de altura Y: 1.03

# %% [markdown]
# ## Revisión por Piso Blando

# %%
sis.show_table(sismo.piso_blando_table)
# Out:
# Dropdown(description='Filtro', index=6, options=('Sy Max', 'Sx Max', 'SDx Max', 'Sy Min', 'SDy Max', 'Sx Min',…
#      Story OutputCase         UX         UY           URX           URY  \
# 0   Story4     Sy Max  1.621E-11    174.736  2.980000e-12  3.166400e+01
# 14             0  -27910768.31  4.910669e+05  3.109102e+05  0.000000e+00
# 15             0  -31064688.75  8.262545e+05  3.437468e+05  3.516431e+05
# 16      0.001423     1042435.8  4.614909e+05  0.000000e+00  0.000000e+00
# 17      0.003908    1848520.84  3.912511e+08  3.230437e+05  0.000000e+00
# 18     0.0001221    2395506.62  5.069822e+05  2.738758e+08  0.000000e+00
# 19          0.01    2643507.74  3.512415e+06  3.548876e+05  1.045919e+08
# 20  -12141166.11             0  3.834375e+05  0.000000e+00  0.000000e+00
# 21  -21602927.43             0  4.441574e+05  2.684063e+05  0.000000e+00
# 22  -27910768.31             0  4.910669e+05  3.109102e+05  0.000000e+00
# 23  -31064688.75             0  8.262545e+05  3.437468e+05  3.516431e+05
#
#        is_reg
# 0     Regular
# 1     Regular
# 2     Regular
# 3     Regular
# 4     Regular
# 5     Regular
# 6     Regular
# 7     Regular
# 8     Regular
# 9     Regular
# 10    Regular
# 11    Regular
# 12    Regular
# 13    Regular
# 14    Regular
# 15    Regular
# 16    Regular
# 17    Regular
# 18  Irregular
# 19  Irregular
# 20    Regular
# 21    Regular
# 22    Regular
# 23    Regular

# %% [markdown]
# ## Revisión por Irregularidad de Masa

# %%
sismo.rev_masa_table
# Out:
#     Story      Mass 1.5_inf_mass 1.5_sup_mass story_type   is_reg
# 0  Story4  531.1727                               Azotea  Regular
# 1  Story3  551.9326                 796.75905     Azotea  Regular
# 2  Story2  551.9326     827.8989                    Piso  Regular
# 3  Story1  551.9326                  827.8989       Piso  Regular
# 4    Base   20.7599                               Sotano  Regular

# %% [markdown]
# ## Revisión de torsión

# %%
sis.show_table(sismo.torsion_table)
# Out:
# Dropdown(description='Filtro', index=6, options=('Sx Max', 'Sx Min', 'Sy Max', 'Sy Min', 'SDx Max', 'SDy Max',…
#      Story OutputCase Direction Max Drift Avg Drift  Ratio Height    Drifts  \
# 0   Story4     Sx Max         X     32.35    32.122  1.007   3000  0.064700
# 1   Story4     Sx Min         X    31.435    31.207  1.007   3000  0.062870
# 2   Story4     Sy Max         Y     32.35    32.122  1.007   3000  0.064700
# 3   Story4     Sy Min         Y    31.435    31.207  1.007   3000  0.062870
# 4   Story4    SDx Max         X     2.741     2.721  1.007   3000  0.005482
# 5   Story4    SDy Max         Y     2.741     2.721  1.007   3000  0.005482
# 6   Story3     Sx Max         X    49.713    49.355  1.007   3000  0.099426
# 7   Story3     Sx Min         X     48.28    47.922  1.007   3000  0.096560
# 8   Story3     Sy Max         Y    49.713    49.355  1.007   3000  0.099426
# 9   Story3     Sy Min         Y     48.28    47.922  1.007   3000  0.096560
# 10  Story3    SDx Max         X     4.217     4.187  1.007   3000  0.008434
# 11  Story3    SDy Max         Y     4.217     4.187  1.007   3000  0.008434
# 12  Story2     Sx Max         X    58.106    57.683  1.007   3000  0.116212
# 13  Story2     Sx Min         X    56.414    55.991  1.008   3000  0.112828
# 14  Story2     Sy Max         Y    58.106    57.683  1.007   3000  0.116212
# 15  Story2     Sy Min         Y    56.414    55.991  1.008   3000  0.112828
# 16  Story2    SDx Max         X     4.944     4.908  1.007   3000  0.009888
# 17  Story2    SDy Max         Y     4.944     4.908  1.007   3000  0.009888
# 18  Story1     Sx Max         X    38.435    38.156  1.007   3000  0.076870
# 19  Story1     Sx Min         X    37.318    37.039  1.008   3000  0.074636
# 20  Story1     Sy Max         Y    38.435    38.156  1.007   3000  0.076870
# 21  Story1     Sy Min         Y    37.318    37.039  1.008   3000  0.074636
# 22  Story1    SDx Max         X     3.267     3.243  1.007   3000  0.006534
# 23  Story1    SDy Max         Y     3.267     3.243  1.007   3000  0.006534
#
#     Drift < Dmax/2  tor_reg
# 0            False  Regular
# 1            False  Regular
# 2            False  Regular
# 3            False  Regular
# 4            False  Regular
# 5            False  Regular
# 6            False  Regular
# 7            False  Regular
# 8            False  Regular
# 9            False  Regular
# 10           False  Regular
# 11           False  Regular
# 12           False  Regular
# 13           False  Regular
# 14           False  Regular
# 15           False  Regular
# 16           False  Regular
# 17           False  Regular
# 18           False  Regular
# 19           False  Regular
# 20           False  Regular
# 21           False  Regular
# 22           False  Regular
# 23           False  Regular

# %% [markdown]
# ## Derivas

# %%
sis.show_table(sismo.drift_table)
# Out:
# Dropdown(description='Filtro', index=6, options=('Sx Max', 'Sx Min', 'Sy Max', 'Sy Min', 'SDx Max', 'SDy Max',…
#      Story OutputCase Direction    Drifts Drift_Check
# 0   Story4     Sx Max         X  0.064700   No Cumple
# 1   Story4     Sx Min         X  0.062870   No Cumple
# 2   Story4     Sy Max         Y  0.064700   No Cumple
# 3   Story4     Sy Min         Y  0.062870   No Cumple
# 4   Story4    SDx Max         X  0.005482      Cumple
# 5   Story4    SDy Max         Y  0.005482      Cumple
# 6   Story3     Sx Max         X  0.099426   No Cumple
# 7   Story3     Sx Min         X  0.096560   No Cumple
# 8   Story3     Sy Max         Y  0.099426   No Cumple
# 9   Story3     Sy Min         Y  0.096560   No Cumple
# 10  Story3    SDx Max         X  0.008434   No Cumple
# 11  Story3    SDy Max         Y  0.008434   No Cumple
# 12  Story2     Sx Max         X  0.116212   No Cumple
# 13  Story2     Sx Min         X  0.112828   No Cumple
# 14  Story2     Sy Max         Y  0.116212   No Cumple
# 15  Story2     Sy Min         Y  0.112828   No Cumple
# 16  Story2    SDx Max         X  0.009888   No Cumple
# 17  Story2    SDy Max         Y  0.009888   No Cumple
# 18  Story1     Sx Max         X  0.076870   No Cumple
# 19  Story1     Sx Min         X  0.074636   No Cumple
# 20  Story1     Sy Max         Y  0.076870   No Cumple
# 21  Story1     Sy Min         Y  0.074636   No Cumple
# 22  Story1    SDx Max         X  0.006534      Cumple
# 23  Story1    SDy Max         Y  0.006534      Cumple

# %% [markdown]
# # Fuerza Cortante Mínima

# %%
sismo.shear_table.style.hide(axis='index').hide(axis='columns')
# Out:
# <style type="text/css">
# </style>
# <table id="T_8964c">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8964c_row0_col0" class="data row0 col0" ></td>
#       <td id="T_8964c_row0_col1" class="data row0 col1" >X</td>
#       <td id="T_8964c_row0_col2" class="data row0 col2" >Y</td>
#     </tr>
#     <tr>
#       <td id="T_8964c_row1_col0" class="data row1 col0" >V din (Ton)</td>
#       <td id="T_8964c_row1_col1" class="data row1 col1" >269.562800</td>
#       <td id="T_8964c_row1_col2" class="data row1 col2" >269.562800</td>
#     </tr>
#     <tr>
#       <td id="T_8964c_row2_col0" class="data row2 col0" >V est (Ton)</td>
#       <td id="T_8964c_row2_col1" class="data row2 col1" >-3167.716600</td>
#       <td id="T_8964c_row2_col2" class="data row2 col2" >-3167.716600</td>
#     </tr>
#     <tr>
#       <td id="T_8964c_row3_col0" class="data row3 col0" >% min</td>
#       <td id="T_8964c_row3_col1" class="data row3 col1" >80</td>
#       <td id="T_8964c_row3_col2" class="data row3 col2" >80</td>
#     </tr>
#     <tr>
#       <td id="T_8964c_row4_col0" class="data row4 col0" >%</td>
#       <td id="T_8964c_row4_col1" class="data row4 col1" >8.510000</td>
#       <td id="T_8964c_row4_col2" class="data row4 col2" >8.510000</td>
#     </tr>
#     <tr>
#       <td id="T_8964c_row5_col0" class="data row5 col0" >F.E.</td>
#       <td id="T_8964c_row5_col1" class="data row5 col1" >9.400000</td>
#       <td id="T_8964c_row5_col2" class="data row5 col2" >9.400000</td>
#     </tr>
#   </tbody>
# </table>

# %%
from mem import sismo_mem as smem
zona = 2
suelo = 'S2'
categoria = sismo.data['Factor de Importancia']

ins = r'''Esto mostrará una lista de los commits en el repositorio, comenzando con el commit más reciente.
Cada commit estará identificado por una cadena de caracteres larga y hexadecimal que aparece en la
línea que comien
'''

section = smem.Section('Análsis Sísmico')
smem.factor_zona(section,zona,o_type=smem.Subsection,insert=ins)
geometry_options = { "left": "2.5cm", "top": "1.5cm" }
section.append('Esto mostrará una lista de los commits en el repositorio, comenzando con el commit más reciente. Cada commit estará identificado por una cadena de caracteres larga y hexadecimal que aparece en la línea que comienz')
doc = smem.Document(geometry_options=geometry_options)
doc.packages.append(smem.Package('xcolor', options=['dvipsnames']))
doc.append(section)
#doc.generate_pdf('Memoria')

# %%
doc.generate_tex('Memoria')

# %%
zona = 3
suelo = 'S0'
section = smem.Section('Análsis Sísmico')
subsection = smem.Subsection('Parámetros de Sitio')
smem.factor_zona(subsection,zona,insert=ins)
smem.factor_suelo(subsection,zona,suelo)
geometry_options = { "left": "2.5cm", "top": "1.5cm" }
section.append('Esto mostrará una lista de los commits en el repositorio, comenzando con el commit más reciente. Cada commit estará identificado por una cadena de caracteres larga y hexadecimal que aparece en la línea que comienz')
doc = smem.Document(geometry_options=geometry_options)
doc.packages.append(smem.Package('xcolor', options=['dvipsnames']))
section.append(subsection)
doc.append(section)
tabla = sismo.torsion_table
sis_x = tabla[tabla['OutputCase']=='SDx Max']
sis_y = tabla[tabla['OutputCase']=='SDy Max']
sis_y = sis_y[sis_y['Direction']=='Y']
section2 = smem.Section('Irregularidades')
smem.irreg_torsion(section2,sis_x,sis_y)
doc.append(section2)
doc.generate_pdf('Memoria')

# %%
tabla = sismo.torsion_table

# %%
tabla
