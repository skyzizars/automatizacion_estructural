# %% [markdown]
# # Análisis Sísmico

# %%
#Inportar las librerías necesarias
# %load_ext autoreload
# %autoreload 2
import os
import sys
sys.path.append(os.getcwd()+'\\..')
from lib import etabs_utils as etb
from lib import sismo_utils as sis
#from mem import sismo_mem as smem
from ipywidgets import widgets
from IPython.display import display

# %%
import comtypes
EtabsObject=comtypes.client.GetActiveObject("CSI.ETABS.API.ETABSObject")
SapModel=EtabsObject.SapModel

# %%
#_, SapModel = etb.connect_to_etabs()
sismo = sis.sismo_e30()

# %% [markdown]
# # Parámetros de Sitio
#
# ## Zonificación
# ![Factor de Zonifiación](./factor_zona.png)

# %% [markdown]
# ## Factor de Suelo
# ![Factor de Suelo](./factor_suelo.png)

# %% [markdown]
# ## Periodos del suelo
# ![Periodos del Suelo](./periodos_suelo.png)

# %% [markdown]
# ## Sistema Estructural
# ![Sistema Estructural](./sistemas_estructurales.png)

# %% [markdown]
# ## Factor de Amplificación sísmica
# ![Factor de Amplificacion Sísmica](./amplificacion_sismica.png)

# %% [markdown]
# ## Factor de Importancia
# ![Factor de Importancia](./factor_importancia.png)

# %%
sismo.parametros_e30()
# Out:
# VBox(children=(Dropdown(description='Factor Zona', index=1, options=('1', '2', '3', '4'), style=DescriptionSty…

# %% [markdown]
# # Irregularidades

# %%
sismo.irregularidades_e30()
# Out:
# HBox(children=(VBox(children=(HTML(value='<b>Irregularidad en Altura</b>'), Checkbox(value=False, description=…

# %% [markdown]
# # Parámetros Sísmicos

# %%
sismo.show_params()
# Out:
# Parámetros de sitio:
# Factor de zona:
#     Z=0.35
# Factor de Importancia:
#     U=1.00
# Factor de Suelo:
#     S=1.20
# Periodos del Suelo:
#     Tp=1.00
#     Tl=1.60
# Factor Básico de Reducción:
#     Rox=7.00
#     Roy=7.00
# Irregularidad en planta:
#     Ipx=1.00
#     Ipy=1.00
# Irregularidad en altura:
#     Iax=1.00
#     Iay=1.00
# Factor de Reducción:
#     Rx=7.00
#     Ry=7.00

# %%
sismo.analisis_sismo(SapModel)
# Out:
# Análisis Modal:
# Masa Participativa X: 0.95
# Masa Participativa Y: 0.86
# ---Aumentar Grados de Libertad 0.86 < 0.9
# Periodo y deformaxión X: Tx=0.042, Ux=0.000
# Periodo y deformaxión Y: Ty=0.032, Uy=0.004
# Factor de Reduccion con Irregularidades: R=7.0
# C en X: 2.50
# C en Y: 2.50
#
# Coeficiente de sismo estático X: 0.150
# Coeficiente de sismo estático Y: 0.150
# Exponente de altura X: 1.00
# Exponente de altura Y: 1.00

# %% [markdown]
# ## Revisión por Piso Blando

# %%
sis.show_table(sismo.piso_blando_table)
# Out:
# Dropdown(description='Filtro', index=5, options=('Sy Max', 'SDy Max', 'Sx Max', 'Sx Min', 'SDx Max', 'Sy Min',…
#      Story OutputCase         UX        UY       URX       URY VX        VY  \
# 40  Story8     Sy Min  -0.000597  0.003745  0.000113  0.000545  0  -18.4866
# 41  Story7     Sy Min   -0.00071    0.0032 -0.000106  0.000566  0  -39.5596
# 42  Story6     Sy Min  -0.000604  0.002634 -0.000122  0.000576  0  -57.4061
# 43  Story5     Sy Min  -0.000482  0.002058 -0.000171  0.000569  0   -72.069
# 44  Story4     Sy Min  -0.000311  0.001489 -0.000118  0.000534  0  -84.1016
# 45  Story3     Sy Min  -0.000193  0.000955 -0.000108  0.000464  0  -92.7918
# 46  Story2     Sy Min   -8.5E-05  0.000491 -0.000013  0.000355  0  -98.1396
# 47  Story1     Sy Min   -7.2E-05  0.000136 -0.000072  0.000136  0  -99.7665
#
#        lat_rig(k)     0.7_prev_k      0.8k_prom   is_reg
# 40   33920.366972       0.000000       0.000000  Regular
# 41   69893.286219   23744.256881       0.000000  Regular
# 42   99663.368056   48925.300353       0.000000  Regular
# 43  126659.050967   69764.357639   54260.538999  Regular
# 44  157493.632959   88661.335677   78990.854731  Regular
# 45  199982.327586  110245.543071  102350.947195  Regular
# 46  276449.577465  139987.629310  129102.669736  Regular
# 47  733577.205882  193514.704225  169046.810136  Regular

# %% [markdown]
# ## Revisión por Irregularidad de Masa

# %%
sismo.rev_masa_table
# Out:
#     Story     Mass 1.5_inf_mass 1.5_sup_mass story_type     is_reg
# 0  Story8  6.66875                               Azotea    Regular
# 1  Story7  8.75356    13.105605                    Piso    Regular
# 2  Story6  8.73707    13.108545     13.13034       Piso    Regular
# 3  Story5  8.73903    13.745145    13.105605       Piso    Regular
# 4  Story4  9.16343    13.745145    13.108545       Piso    Regular
# 5  Story3  9.16343    13.745145    13.745145       Piso    Regular
# 6  Story2  9.16343    11.150445    13.745145       Piso    Regular
# 7  Story1  7.43363     5.340225    13.745145       Piso  Irregular
# 8      NT  3.56015                 11.150445       Piso    Regular
# 9    Base  3.91769                               Sotano    Regular

# %% [markdown]
# ## Revisión de torsión

# %%
sis.show_table(sismo.torsion_table)
# Out:
# Dropdown(description='Filtro', index=5, options=('Sx Max', 'Sx Min', 'Sy Max', 'Sy Min', 'SDx Max', 'SDy Max',…
#      Story OutputCase Direction Max Drift Avg Drift  Ratio Height    Drifts  \
# 7   Story8    SDy Max         X  0.000535  0.000322  1.662    2.5  0.001123
# 8   Story8    SDy Max         Y  0.000498  0.000478  1.042    2.5  0.001046
# 16  Story7    SDy Max         X   0.00059  0.000357   1.65    2.5  0.001239
# 17  Story7    SDy Max         Y  0.000527   0.00051  1.033    2.5  0.001107
# 25  Story6    SDy Max         X  0.000632  0.000387  1.633    2.5  0.001327
# 26  Story6    SDy Max         Y  0.000533  0.000517  1.031    2.5  0.001119
# 34  Story5    SDy Max         X   0.00065  0.000402  1.618    2.5  0.001365
# 35  Story5    SDy Max         Y  0.000523  0.000506  1.034    2.5  0.001098
# 43  Story4    SDy Max         X  0.000637  0.000397  1.605    2.5  0.001338
# 44  Story4    SDy Max         Y  0.000488  0.000471  1.035    2.5  0.001025
# 52  Story3    SDy Max         X  0.000577  0.000361  1.597    2.5  0.001212
# 53  Story3    SDy Max         Y  0.000423  0.000407  1.038    2.5  0.000888
# 60  Story2    SDy Max         X   0.00046  0.000287  1.602    2.5  0.000966
# 61  Story2    SDy Max         Y  0.000332  0.000313  1.058    2.5  0.000697
# 69  Story1    SDy Max         X  0.000167  0.000103  1.625    1.5  0.000584
# 70  Story1    SDy Max         Y  0.000126  0.000108  1.173    1.5  0.000441
# 79      NT    SDy Max         X   3.3E-05   1.6E-05      2   1.75  0.000099
# 80      NT    SDy Max         Y   2.7E-05   1.3E-05      2   1.75  0.000081
#
#     Drift < Dmax/2  tor_reg
# 7             True  Regular
# 8             True  Regular
# 16            True  Regular
# 17            True  Regular
# 25            True  Regular
# 26            True  Regular
# 34            True  Regular
# 35            True  Regular
# 43            True  Regular
# 44            True  Regular
# 52            True  Regular
# 53            True  Regular
# 60            True  Regular
# 61            True  Regular
# 69            True  Regular
# 70            True  Regular
# 79            True  Regular
# 80            True  Regular

# %% [markdown]
# ## Derivas

# %%
sis.show_table(sismo.drift_table)
# Out:
# Dropdown(description='Filtro', index=6, options=('Sx Max', 'Sx Min', 'Sy Max', 'Sy Min', 'SDx Max', 'SDy Max',…
#      Story OutputCase Direction    Drifts Drift_Check
# 0   Story8     Sx Max         X  0.007778   No Cumple
# 1   Story8     Sx Min         X  0.006628      Cumple
# 2   Story8     Sy Max         X  0.001077      Cumple
# 3   Story8     Sy Max         Y  0.001569      Cumple
# 4   Story8     Sy Min         X  0.000932      Cumple
# ..     ...        ...       ...       ...         ...
# 76      NT     Sy Min         Y  0.000096      Cumple
# 77      NT    SDx Max         X  0.000720      Cumple
# 78      NT    SDx Max         Y  0.000084      Cumple
# 79      NT    SDy Max         X  0.000099      Cumple
# 80      NT    SDy Max         Y  0.000081      Cumple
#
# [81 rows x 5 columns]

# %% [markdown]
# # Fuerza Cortante Mínima

# %%
sismo.shear_table.style.hide(axis='index').hide(axis='columns')
# Out:
# <style type="text/css">
# </style>
# <table id="T_af262">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_af262_row0_col0" class="data row0 col0" ></td>
#       <td id="T_af262_row0_col1" class="data row0 col1" >X</td>
#       <td id="T_af262_row0_col2" class="data row0 col2" >Y</td>
#     </tr>
#     <tr>
#       <td id="T_af262_row1_col0" class="data row1 col0" >V din (Ton)</td>
#       <td id="T_af262_row1_col1" class="data row1 col1" >50.889600</td>
#       <td id="T_af262_row1_col2" class="data row1 col2" >65.187100</td>
#     </tr>
#     <tr>
#       <td id="T_af262_row2_col0" class="data row2 col0" >V est (Ton)</td>
#       <td id="T_af262_row2_col1" class="data row2 col1" >-62.840400</td>
#       <td id="T_af262_row2_col2" class="data row2 col2" >-81.319000</td>
#     </tr>
#     <tr>
#       <td id="T_af262_row3_col0" class="data row3 col0" >% min</td>
#       <td id="T_af262_row3_col1" class="data row3 col1" >80</td>
#       <td id="T_af262_row3_col2" class="data row3 col2" >80</td>
#     </tr>
#     <tr>
#       <td id="T_af262_row4_col0" class="data row4 col0" >%</td>
#       <td id="T_af262_row4_col1" class="data row4 col1" >80.980000</td>
#       <td id="T_af262_row4_col2" class="data row4 col2" >80.160000</td>
#     </tr>
#     <tr>
#       <td id="T_af262_row5_col0" class="data row5 col0" >F.E.</td>
#       <td id="T_af262_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_af262_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
from mem import sismo_mem as smem
zona = 2
suelo = 'S2'
categoria = sismo.data['Factor de Importancia']

ins = r'''Esto mostrará una lista de los commits en el repositorio, comenzando con el commit más reciente.
Cada commit estará identificado por una cadena de caracteres larga y hexadecimal que aparece en la
línea que comien
'''

section = smem.Section('Análsis Sísmico')
smem.factor_zona(section,zona,o_type=smem.Subsection,insert=ins)
geometry_options = { "left": "2.5cm", "top": "1.5cm" }
section.append('Esto mostrará una lista de los commits en el repositorio, comenzando con el commit más reciente. Cada commit estará identificado por una cadena de caracteres larga y hexadecimal que aparece en la línea que comienz')
doc = smem.Document(geometry_options=geometry_options)
doc.packages.append(smem.Package('xcolor', options=['dvipsnames']))
doc.append(section)
doc.generate_pdf('Memoria')

# %%
doc.generate_tex('Memoria')

# %%
zona = 3
suelo = 'S0'
section = smem.Section('Análsis Sísmico')
subsection = smem.Subsection('Parámetros de Sitio')
smem.factor_zona(subsection,zona,insert=ins)
smem.factor_suelo(subsection,zona,suelo)
geometry_options = { "left": "2.5cm", "top": "1.5cm" }
section.append('Esto mostrará una lista de los commits en el repositorio, comenzando con el commit más reciente. Cada commit estará identificado por una cadena de caracteres larga y hexadecimal que aparece en la línea que comienz')
doc = smem.Document(geometry_options=geometry_options)
doc.packages.append(smem.Package('xcolor', options=['dvipsnames']))
section.append(subsection)
doc.append(section)
tabla = sismo.torsion_table
sis_x = tabla[tabla['OutputCase']=='SDx Max']
sis_y = tabla[tabla['OutputCase']=='SDy Max']
sis_y = sis_y[sis_y['Direction']=='Y']
section2 = smem.Section('Irregularidades')
smem.irreg_torsion(section2,sis_x,sis_y)
doc.append(section2)
doc.generate_pdf('Memoria')

# %%
tabla = sismo.torsion_table

# %%
tabla
# Out:
#      Story OutputCase Direction Max Drift Avg Drift   Ratio Height    Drifts  \
# 0   Story8     Sx Max         X  0.003536  0.003073   1.151    2.5  0.007426
# 1   Story8     Sx Min         X  0.003013  0.002589   1.163    2.5  0.006327
# 2   Story8     Sy Max         X   0.00046  0.000107   4.305    2.5  0.000966
# 3   Story8     Sy Max         Y  0.000671  0.000564    1.19    2.5  0.001409
# 4   Story8     Sy Min         X  0.000399   7.8E-05   5.118    2.5  0.000838
# ..     ...        ...       ...       ...       ...     ...    ...       ...
# 76      NT     Sy Min         Y   2.9E-05     1E-06  40.601   1.75  0.000087
# 77      NT    SDx Max         X   0.00024   0.00012       2   1.75  0.000720
# 78      NT    SDx Max         Y   2.8E-05   1.4E-05       2   1.75  0.000084
# 79      NT    SDy Max         X   3.3E-05   1.6E-05       2   1.75  0.000099
# 80      NT    SDy Max         Y   2.7E-05   1.3E-05       2   1.75  0.000081
#
#     Drift < Dmax/2  tor_reg
# 0            False  Regular
# 1            False  Regular
# 2             True  Regular
# 3             True  Regular
# 4             True  Regular
# ..             ...      ...
# 76            True  Regular
# 77            True  Regular
# 78            True  Regular
# 79            True  Regular
# 80            True  Regular
#
# [81 rows x 10 columns]
